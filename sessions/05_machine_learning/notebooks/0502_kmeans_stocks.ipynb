# %% [markdown]
# ## Clustering stocks using KMeans
#
# In this exercise, you'll cluster companies using their daily stock price movements (i.e. the dollar difference between the closing and opening prices for each trading day).  You are given a NumPy array `movements` of daily price movements from 2010 to 2015, where each row corresponds to a company, and each column corresponds to a trading day.
#
# Some stocks are more expensive than others.  To account for this, include a `Normalizer` at the beginning of your pipeline.  The Normalizer will separately transform each company's stock price to a relative scale before the clustering begins.
#
# # Normalizer vs StandardScaler
# Note that `Normalizer()` is different to `StandardScaler()`, which you used in the previous exercise. While `StandardScaler()` standardizes **features** (such as the features of the fish data from the previous exercise) by removing the mean and scaling to unit variance, `Normalizer()` rescales **each sample** - here, each company's stock price - independently of the other.
#
# This dataset was obtained from the Yahoo! Finance API.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Load the data  (written for you)

# %%
path = 'https://raw.githubusercontent.com/frandiego/data/master/stocks.csv'
df = pd.read_csv(path, index_col='company')

# %% [markdown]
# ## 2. Inspect the first few rows of the DataFrame `stocks_df` by calling its `head()` function. (written for you)

# %%
df.head()
# Out:
#                   2010-01-04  2010-01-05  ...  2013-10-28  2013-10-29
# company                                   ...
# Apple               0.580000   -0.220005  ...    0.840019  -19.589981
# AIG                -0.640002   -0.650000  ...   -0.400002    0.660000
# Amazon             -2.350006    1.260009  ...   -1.760009    3.740021
# American express    0.109997    0.000000  ...    0.040001    0.540001
# Boeing              0.459999    1.770000  ...    1.130005    0.309998
#
# [5 rows x 963 columns]

# %% [markdown]
# ## 3. Extract the NumPy array `movements` from the DataFrame and the list of company names (_written for you_)

# %%
companies = list(df.index)
movements = df.values

# %% [markdown]
# ## 4. Make the necessary imports:
#
# - `Normalizer` from `sklearn.preprocessing`.
# - `KMeans` from `sklearn.cluster`.
# - `make_pipeline` from `sklearn.pipeline`.

# %%
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans
from sklearn.pipeline import make_pipeline

# %% [markdown]
# ## 5. Create an instance of `Normalizer` called `normalizer`.

# %%
normalizer = Normalizer()

# %%
mvtr = normalizer.fit_transform(movements)

# %% [markdown]
# ## 6. Create an instance of `KMeans` called `kmeans` with `10` clusters.

# %%
kmeans = KMeans(n_clusters=10)

# %% [markdown]
# ##  7. Using `make_pipeline()`, create a pipeline called `pipeline` that chains `normalizer` and `kmeans`. Please read this [link](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.make_pipeline.html)

# %%
pipeline = make_pipeline( kmeans)

# %% [markdown]
# ## 8. Fit the pipeline to the `movements` array.

# %%
pipeline.fit(movements)
# Out:
# Pipeline(memory=None,
#          steps=[('normalizer', Normalizer(copy=True, norm='l2')),
#                 ('kmeans',
#                  KMeans(algorithm='auto', copy_x=True, init='k-means++',
#                         max_iter=300, n_clusters=20, n_init=10, n_jobs=None,
#                         precompute_distances='auto', random_state=None,
#                         tol=0.0001, verbose=0))],
#          verbose=False)

# %% [markdown]
# ## 9.  Use the `.predict()` method of the pipeline to predict the labels for `movements`.

# %%
labels = kmeans.fit_predict(mvtr)

# %%
labels
# Out:
# array([9, 0, 7, 0, 3, 0, 5, 6, 2, 8, 2, 1, 2, 2, 1, 0, 0, 9, 0, 5, 6, 6,
#        1, 2, 1, 4, 0, 8, 8, 3, 6, 2, 2, 1, 6, 2, 3, 5, 8, 5, 8, 8, 5, 5,
#        2, 6, 5, 1, 6, 5, 1, 1, 5, 2, 4, 0, 8, 2, 0, 7], dtype=int32)

# %% [markdown]
# ## 10. Align the cluster labels with the list of company names `companies` by creating a DataFrame `result` with `labels` and `companies` as columns.

# %%
result = pd.DataFrame({'labels': labels, 'companies': companies})

# %% [markdown]
# ## 11. Now display the DataFrame, sorted by cluster label.  To do this, use the `.sort_values()` method of `result` to sort the DataFrame by the `'labels'` column.

# %%
for i in result.labels.unique():
    print(i)
    print(result.loc[result.labels == i,'companies'])
    print('')
# Out:
# 9
# 0               Apple
# 17    Google/Alphabet
# Name: companies, dtype: object
#
# 0
# 1                   AIG
# 3      American express
# 5       Bank of America
# 15                 Ford
# 16    General Electrics
# 18        Goldman Sachs
# 26       JPMorgan Chase
# 55          Wells Fargo
# 58                Xerox
# Name: companies, dtype: object
#
# 7
# 2     Amazon
# 59     Yahoo
# Name: companies, dtype: object
#
# 3
# 4               Boeing
# 29     Lookheed Martin
# 36    Northrop Grumman
# Name: companies, dtype: object
#
# 5
# 6     British American Tobacco
# 19             GlaxoSmithKline
# 37                    Novartis
# 39                      Pfizer
# 42           Royal Dutch Shell
# 43                         SAP
# 46              Sanofi-Aventis
# 49                       Total
# 52                    Unilever
# Name: companies, dtype: object
#
# 6
# 7          Canon
# 20    Home Depot
# 21         Honda
# 30    MasterCard
# 34    Mitsubishi
# 45          Sony
# 48        Toyota
# Name: companies, dtype: object
#
# 2
# 8           Caterpillar
# 10       ConocoPhillips
# 12              Chevron
# 13    DuPont de Nemours
# 23                  IBM
# 31            McDonalds
# 32                   3M
# 35             Navistar
# 44         Schlumberger
# 53        Valero Energy
# 57                Exxon
# Name: companies, dtype: object
#
# 8
# 9     Colgate-Palmolive
# 27       Kimberly-Clark
# 28            Coca Cola
# 38                Pepsi
# 40       Procter Gamble
# 41        Philip Morris
# 56             Wal-Mart
# Name: companies, dtype: object
#
# 1
# 11                                 Cisco
# 14                                  Dell
# 22                                    HP
# 24                                 Intel
# 33                             Microsoft
# 47                              Symantec
# 50    Taiwan Semiconductor Manufacturing
# 51                     Texas instruments
# Name: companies, dtype: object
#
# 4
# 25    Johnson & Johnson
# 54             Walgreen
# Name: companies, dtype: object

# %%
result.sort_values('labels').head()
# Out:
#     labels   companies
# 14       0        Dell
# 21       1       Honda
# 48       1      Toyota
# 7        1       Canon
# 34       1  Mitsubishi

# %%
dftr = normalizer.fit_transform(df)

# %%
dftr = pd.DataFrame(dftr)

# %%
dftr.index = df.index

# %%
dftr.head()
# Out:
#                        0         1         2    ...       960       961       962
# company                                         ...
# Apple             0.003021 -0.001146 -0.017759  ... -0.027913  0.004375 -0.102020
# AIG              -0.025994 -0.026400 -0.008529  ... -0.001625 -0.016246  0.026806
# Amazon           -0.022090  0.011844 -0.022090  ...  0.045026 -0.016544  0.035156
# American express  0.005214  0.000000  0.012324  ...  0.087687  0.001896  0.025595
# Boeing            0.015641  0.060184  0.052703  ...  0.065964  0.038423  0.010541
#
# [5 rows x 963 columns]

# %%
for i in np.sort(result.labels.unique()):
    companies_i = list(result.loc[result.labels == i,'companies'])
    dftr[dftr.index.isin(companies_i)].T.plot()

# %%
dftr = dftr.reset_index()

# %%
dftr['label'] = labels

# %%
dftrm = dftr.melt(['company','label'])

# %%
dftrm['value_cluster'] = dftrm.groupby([dftrm.label])['value'].transform(np.mean)

# %%
dftrm['error'] = (dftrm['value'] - dftrm['value_cluster']) ** 2

# %%
dftrm.groupby('label').agg({'error':'mean'}).reset_index()
# Out:
#    label     error
# 0      0  0.001038
# 1      1  0.001038
# 2      2  0.001038
# 3      3  0.001035
# 4      4  0.001034
# 5      5  0.001034
# 6      6  0.001035
# 7      7  0.001038
# 8      8  0.001032
# 9      9  0.001037
